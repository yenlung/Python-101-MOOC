# %% [markdown]
# ## 🎯 本課重點
#
# 1. 認識這門課的學習方式（包括用 ChatGPT 當學習夥伴！）
# 2. 學會使用 Colab
# 3. 匯入 NumPy、Pandas、Matplotlib 等基本套件
# 4. 畫出第一張數學圖形！

# %% [markdown]
# ## 🔧 開始設定 Colab 和常用套件
#
# 建議大家永遠要讀進來的三個套件!
#
# - `numpy`: 數學與陣列計算
# - `pandas`: 資料處理好幫手
# - `matplotlib`: 畫圖用！

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 現在來畫出我們第一張數學圖形吧：$y = \sin(x)$

# %% [markdown]
# ## 📈 畫出 $y = \sin(x)$ 的圖形

# %%
x = np.linspace(-10, 10, 200)

# %% [markdown]
# 注意 `numpy` 才懂得 `sin`

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %% [markdown]
# ## 🎨 改成漫畫風格（xkcd）來試試看！

# %%
plt.xkcd()

# %%
plt.plot(x, y)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# ...

# %% [markdown]
# ---
#
# ## 📝 自己出題自己做：創意練習區
#
# 請你根據這一課的內容，自己想一個可以畫圖的數學式子，像這樣：
#
# - 畫出 $y = \cos(x)$、$y = \exp(-x^2)$ 等數學函數
# - 問問 AI，你怎麼可以把線條加粗、用不同的顏色
# - 當然也可以問 ChatGPT：「請幫我想一些可以畫出有趣圖形的函數」，然後畫出來
# - 有時你會找到不連續的函數，比如 $\tan(x)$，試試能不能請 ChatGPT 幫忙你解決問題。
#
# 試著讓你畫出來的圖跟大家的不一樣吧！
