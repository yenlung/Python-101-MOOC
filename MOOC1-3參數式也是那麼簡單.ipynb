# %% [markdown]
# ## 🎯 本課重點
#
# 這一課我們會更深入探索畫圖的方式，包括：
#
# - 用數學公式畫出有趣圖形（例如心型！）
# - 認識「極座標系統」的畫法
# - 初步介紹 Seaborn 這個強大的視覺化套件

# %% [markdown]
# ## 1. 匯入常用繪圖工具

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. 回顧：函數圖形繪製
#
# 這是前面畫過的 $y = \cos(x)$：

# %%
x = np.linspace(-4, 6, 200)
y = np.cos(x)
plt.plot(x, y);

# %% [markdown]
# ## 🔍 3. `plot()` 和 `scatter()` 有什麼差別？
#
# 來看一下用 `plt.scatter` 畫點與 `plt.plot` 的不同：

# %%
x = [1, 2, 3, 4]
y = [4, -2, 5, 1]

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

# %% [markdown]
# ## 4. 極座標換成參數式
#
# \begin{cases}
# x = r \cdot \cos(t) \\
# y = r \cdot \sin(t)
# \end{cases}
#
# 其中 $t$ 是角度, 一般是 $0$ 到 $2 \pi$。

# %% [markdown]
# 比如說，一個半徑是 3 的圓是 $r=3$，換成我們習慣的座標系統就是:
#
# $t$ 取 $0$ 到 $2\pi$ 的若干點，
# \begin{cases}
# x = 3 \cdot \cos(t)\\
# y = 3 \cdot \sin(t)
# \end{cases}

# %%
pi = np.pi

# %%
t = np.linspace(0, 2*pi, 400)

# %%
r = 3

# %%
x = r * np.cos(t)
y = r * np.sin(t)

# %%
plt.plot(x,y)

# %%
plt.axis("equal")
plt.plot(x,y)

# %% [markdown]
# ## 4. 用參數式畫出心型圖
#
# $r = 1 - \sin(t)$

# %%
t = np.linspace(0, 2*pi, 300)
r = 1 - np.sin(t)

# %%
x = r * np.cos(t)
y = r * np.sin(t)

# %%
plt.plot(x,y);
plt.axis("equal");

# %% [markdown]
# ## 📝 自己出題自己做！
#
# - 試著畫出你自己的圖形，例如星星、花瓣、螺旋、蝸牛……
# - 可以讓 ChatGPT 教你，怎麼畫出填滿的、紅色的心嗎?
# - 最重要的是：找一個你自己看得懂、看得開心的資料和圖！
