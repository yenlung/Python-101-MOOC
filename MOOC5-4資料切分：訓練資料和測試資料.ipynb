# %% [markdown]
# <a href="https://colab.research.google.com/github/yenlung/Python-101-MOOC/blob/main/MOOC5-4%E8%B3%87%E6%96%99%E5%88%87%E5%88%86%EF%BC%9A%E8%A8%93%E7%B7%B4%E8%B3%87%E6%96%99%E5%92%8C%E6%B8%AC%E8%A9%A6%E8%B3%87%E6%96%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 200)
y = 1.2*x + 0.8 + 0.4 * np.random.randn(200)

# %%
plt.scatter(x, y);

# %%
from sklearn.model_selection import train_test_split

# %%
x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                    test_size=0.3,
                                                    random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
x = x_test.reshape(-1) # x = x_test.ravel()
y = y_test.reshape(-1)
plt.scatter(x, y);
Y = y_pred.reshape(-1)
plt.plot(x, Y, color='red');

# %%
r2_score = model.score(x_test, y_test)
print(f"R^2 score: {r2_score}")
# Out:
# R^2 score: 0.9525453153577627
