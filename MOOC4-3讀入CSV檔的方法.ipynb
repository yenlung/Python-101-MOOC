# %% [markdown]
# <a href="https://colab.research.google.com/github/yenlung/Python-101-MOOC/blob/main/MOOC4-3%E8%AE%80%E5%85%A5CSV%E6%AA%94%E7%9A%84%E6%96%B9%E6%B3%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %%writefile "grades.csv"
# 姓名,平時,期中,期末
# 哆啦A夢,87,82,85
# 大雄,12,0,60
# 宜靜,99,98,98
# 技安,55,44,62
# Out:
# Writing grades.csv

# %%
df = pd.read_csv("grades.csv")

# %%
df
# Out:
#      姓名  平時  期中  期末
# 0  哆啦A夢  87  82  85
# 1    大雄  12   0  60
# 2    宜靜  99  98  98
# 3    技安  55  44  62
