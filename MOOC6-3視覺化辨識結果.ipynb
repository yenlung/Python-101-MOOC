# %% [markdown]
# <a href="https://colab.research.google.com/github/yenlung/Python-101-MOOC/blob/main/MOOC6-3%E8%A6%96%E8%A6%BA%E5%8C%96%E8%BE%A8%E8%AD%98%E7%B5%90%E6%9E%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
X = iris.data
Y = iris.target

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
X_pca.shape
# Out:
# (150, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X_pca, Y,
                                                    test_size=0.2,
                                                    random_state=42)

# %%
# 打造一個 SVM 函數學機

from sklearn.svm import SVC

# %%
clf = SVC()

# %%
clf.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_predict = clf.predict(x_test)

# %%
plt.scatter(x_test[:, 0], x_test[:, 1], c=y_predict-y_test);
