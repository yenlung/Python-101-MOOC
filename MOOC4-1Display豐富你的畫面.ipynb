# %% [markdown]
# <a href="https://colab.research.google.com/github/yenlung/Python-101-MOOC/blob/main/MOOC4-1Display%E8%B1%90%E5%AF%8C%E4%BD%A0%E7%9A%84%E7%95%AB%E9%9D%A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from IPython.display import display, HTML, Markdown, Image

# %%
egg = Markdown(r"## 你好!")

# %%
display(egg)
# Out:
# ## 你好!

# %%
ham = r'''我們定義一個函數:

$$f(x) = x^2$$'''

# %%
egg = Markdown(ham)

# %%
display(egg)
# Out:
# 我們定義一個函數:
#
# $$f(x) = x^2$$

# %%
dive = Image('dive_small.png')

# %%
display(dive)
