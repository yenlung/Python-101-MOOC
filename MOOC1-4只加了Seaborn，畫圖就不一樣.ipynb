# %% [markdown]
# <a href="https://colab.research.google.com/github/yenlung/Python-101-MOOC/blob/main/MOOC1-4%E5%8F%AA%E5%8A%A0%E4%BA%86Seaborn%EF%BC%8C%E7%95%AB%E5%9C%96%E5%B0%B1%E4%B8%8D%E4%B8%80%E6%A8%A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🎯 本課重點
#
# 這一課我們會更深入探索畫圖的方式，包括：
#
# - 怎麼在 Matplotlib 裡用中文
# - 初步介紹 Seaborn 這個強大的視覺化套件

# %% [markdown]
# ## 1. 匯入標準工具

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. 讓 Matplotlib 可以顯示中文

# %% [markdown]
# 執行這段，和你自己上網找到 `NotoSansTC.zip` 那個檔案下載，並上傳至 Colab 是一樣的!

# %%
# !wget -O Noto_Sans_TC.zip "https://yenlung.me/NotoSansTC"
# Out:
# --2025-06-30 04:33:28--  https://yenlung.me/NotoSansTC
# Resolving yenlung.me (yenlung.me)... 67.199.248.12, 67.199.248.13
# Connecting to yenlung.me (yenlung.me)|67.199.248.12|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/yenlung/AI-Demo/raw/7c4321c41d5278af62ca3083b28e4ba8321e2894/fonts/Noto_Sans_TC.zip [following]
# --2025-06-30 04:33:29--  https://github.com/yenlung/AI-Demo/raw/7c4321c41d5278af62ca3083b28e4ba8321e2894/fonts/Noto_Sans_TC.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/yenlung/AI-Demo/7c4321c41d5278af62ca3083b28e4ba8321e2894/fonts/Noto_Sans_TC.zip [following]
# --2025-06-30 04:33:30--  https://raw.githubusercontent.com/yenlung/AI-Demo/7c4321c41d5278af62ca3083b28e4ba8321e2894/fonts/Noto_Sans_TC.zip
# ...

# %% [markdown]
# 解壓縮。

# %%
# !unzip Noto_Sans_TC.zip
# Out:
# Archive:  Noto_Sans_TC.zip
#  extracting: OFL.txt
#  extracting: README.txt
#  extracting: static/NotoSansTC-Thin.ttf
#  extracting: static/NotoSansTC-Light.ttf
#  extracting: static/NotoSansTC-Black.ttf
#  extracting: static/NotoSansTC-ExtraLight.ttf
#  extracting: static/NotoSansTC-ExtraBold.ttf
#  extracting: static/NotoSansTC-Regular.ttf
#  extracting: static/NotoSansTC-SemiBold.ttf
#  extracting: static/NotoSansTC-Bold.ttf
#  extracting: static/NotoSansTC-Medium.ttf
#  extracting: NotoSansTC-VariableFont_wght.ttf

# %% [markdown]
# 為了處理字型讀入的。

# %%
import matplotlib as mpl

# %%
mpl.font_manager.fontManager.addfont('static/NotoSansTC-Bold.ttf')
mpl.rc('font', family='Noto Sans TC')

# %% [markdown]
# ### 3. 先標準畫圖來一次

# %%
x = np.linspace(-5, 5, 200)
y = x**2

# %%
plt.title('一個函數的圖形')
plt.plot(x,y);

# %% [markdown]
# ### 4. 打開 Seaborn 魔法

# %%
import seaborn as sns

# %%
sns.set()

# %%
plt.title('一個函數的圖形')
plt.plot(x,y);
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 20491 (\N{CJK UNIFIED IDEOGRAPH-500B}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 20989 (\N{CJK UNIFIED IDEOGRAPH-51FD}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 25976 (\N{CJK UNIFIED IDEOGRAPH-6578}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# ### 5. 需要先進入 Seaborn 狀態，再設定中文

# %%
mpl.font_manager.fontManager.addfont('static/NotoSansTC-Bold.ttf')
mpl.rc('font', family='Noto Sans TC')

# %%
plt.title('一個函數的圖形')
plt.plot(x,y);
