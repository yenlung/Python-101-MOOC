# %% [markdown]
# <a href="https://colab.research.google.com/github/yenlung/Python-101-MOOC/blob/main/MOOC4-7%E7%8E%A9%E7%8E%A9%E7%9C%9F%E7%9A%84%E8%82%A1%E7%A5%A8%E8%B3%87%E6%96%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
df = yf.download('2330.TW', start='2024-01-01', end='2025-06-30')
# Out:
# /tmp/ipython-input-4-2339802611.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('2330.TW', start='2024-01-01', end='2025-06-30')
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker         2330.TW     2330.TW     2330.TW     2330.TW   2330.TW
# Date
# 2024-01-02  585.360962  585.360962  581.412490  582.399608  26059058
# 2024-01-03  570.554199  577.464025  568.579963  576.476907  37106763
# 2024-01-04  572.528442  573.515560  569.567088  572.528442  15309129
# 2024-01-05  568.579956  572.528428  566.605720  570.554192  18158971
# 2024-01-08  575.489746  577.463982  571.541274  574.502628  17761275

# %%
df.tail()
# Out:
# Price        Close    High     Low    Open    Volume
# Ticker     2330.TW 2330.TW 2330.TW 2330.TW   2330.TW
# Date
# 2025-06-23  1020.0  1030.0  1015.0  1025.0  32143872
# 2025-06-24  1050.0  1050.0  1040.0  1045.0  28163537
# 2025-06-25  1070.0  1070.0  1055.0  1060.0  38783736
# 2025-06-26  1075.0  1080.0  1065.0  1075.0  36056692
# 2025-06-27  1080.0  1080.0  1060.0  1070.0  32549027

# %%
close = df.Close

# %%
close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
close.rolling(20).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
close.plot()
close.rolling(20).mean().plot()

# %%
plt.plot(close.values)
plt.plot(close.rolling(20).mean().values)
