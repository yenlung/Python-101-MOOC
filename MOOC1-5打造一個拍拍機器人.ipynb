# %% [markdown]
# ## 1. 讀入我們的標準套件

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. 先來個 Hello, World!

# %%
print("hello, world!")
# Out:
# hello, world!

# %% [markdown]
# ### 3. 最基礎的互動 -- `input`

# %%
name = input("請輸入你的名字：")
# Out:
# 請輸入你的名字：炎龍

# %%
print("你好, " + name + "!")
# Out:
# 你好, 炎龍!

# %% [markdown]
# 當然, 我們可以做有「意義」一點的東西。

# %%
exchange_rate = 29.16

# %%
amount = input("請輸入要換算的金額：")
# Out:
# 請輸入要換算的金額：499

# %%
twd = float(amount) * exchange_rate

# %%
print("換算成台幣為：", twd, "元")
# Out:
# 換算成台幣為： 14550.84 元

# %% [markdown]
# ## 4. 拍拍機器人 1.0

# %%
input("> ")
print("拍拍")
# Out:
# > 今天很難過。
# 拍拍

# %%
prompt = input("> ")
print("( ੭˙ᗜ˙)੭: 拍拍")
# Out:
# > 今天很難過
# ( ੭˙ᗜ˙)੭: 拍拍

# %%
bot_avatar = "( ੭˙ᗜ˙)੭"

# %%
prompt = input("> ")
reply = "拍拍"
print(bot_avatar + ": " + reply)
# Out:
# > 今天很難過
# ( ੭˙ᗜ˙)੭: 拍拍
